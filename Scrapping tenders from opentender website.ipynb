# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
r=requests.get("https://opentender.eu/all/dashboards/market-analysis")

# %%
soup=bs(r.content)
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-NQSM6DP');</script>
# <!-- End Google Tag Manager -->
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <title>Market Analysis - Opentender All Data</title>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="Opentender - Making Public Tenders More Transparent" name="description"/>
# <meta content="Open Data,Tender,Procurement" name="keywords"/>
# <meta content="digiwhist" name="author"/>
# ...

# %%
contents=soup.prettify()

# %%
print(contents)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-NQSM6DP');
#   </script>
#   <!-- End Google Tag Manager -->
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8"/>
#   <title>
#    Market Analysis - Opentender All Data
#   </title>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="Opentender - Making Public Tenders More Transparent" name="description"/>
#   <meta content="Open Data,Tender,Procurement" name="keywords"/>
#   <meta content="digiwhist" name="author"/>
# ...

# %%
table=soup.find('tbody')
table
# Out:
# <tbody><tr>
# <th>Sector Profile</th>
# <th>CPV</th>
# <th>Name</th>
# <th>Nr. of Tenders</th>
# <th>Volume of Tenders (€)</th>
# </tr>
# <!-- --><tr>
# <td><a href="/all/sector/33"><i class="icon-hammer icon-large"></i></a></td>
# <td>33</td>
# <td>Medical equipments, pharmaceuticals and personal care products</td>
# <td>4.6 Million</td>
# <td>€ 576.7 Billion</td>
# </tr><tr>
# <td><a href="/all/sector/30"><i class="icon-hammer icon-large"></i></a></td>
# <td>30</td>
# <td>Office and computing machinery, equipment and supplies except furniture and software packages</td>
# <td>3.1 Million</td>
# <td>€ 102.6 Billion</td>
# </tr><tr>
# <td><a href="/all/sector/15"><i class="icon-hammer icon-large"></i></a></td>
# <td>15</td>
# <td>Food, beverages, tobacco and related products</td>
# <td>3.0 Million</td>
# <td>€ 57.2 Billion</td>
# </tr><tr>
# <td><a href="/all/sector/45"><i class="icon-hammer icon-large"></i></a></td>
# <td>45</td>
# <td>Construction work</td>
# <td>2.6 Million</td>
# ...

# %%
a=[]
for i in table.find_all('td'):
    a.append(table.get_text().split('\n'))
a
# Out:
# [['',
#   'Sector Profile',
#   'CPV',
#   'Name',
#   'Nr. of Tenders',
#   'Volume of Tenders (€)',
#   '',
#   '',
#   '',
#   '33',
#   'Medical equipments, pharmaceuticals and personal care products',
#   '4.6 Million',
#   '€ 576.7 Billion',
#   '',
#   '',
#   '30',
#   'Office and computing machinery, equipment and supplies except furniture and software packages',
#   '3.1 Million',
#   '€ 102.6 Billion',
#   '',
#   '',
#   '15',
#   'Food, beverages, tobacco and related products',
#   '3.0 Million',
#   '€ 57.2 Billion',
#   '',
#   '',
#   '45',
#   'Construction work',
#   '2.6 Million',
#   '€ 1.8 Trillion',
#   '',
#   '',
#   '39',
#   'Furniture (incl. office furniture), furnishings, domestic appliances (excl. lighting) and cleaning products',
#   '2.1 Million',
#   '€ 60.6 Billion',
#   '',
#   '',
#   '44',
#   'Construction structures and materials; auxiliary products to construction (except electric apparatus)',
#   '1.8 Million',
#   '€ 80.8 Billion',
#   '',
# ...

# %%
z=a[0]
z
# Out:
# ['',
#  'Sector Profile',
#  'CPV',
#  'Name',
#  'Nr. of Tenders',
#  'Volume of Tenders (€)',
#  '',
#  '',
#  '',
#  '33',
#  'Medical equipments, pharmaceuticals and personal care products',
#  '4.6 Million',
#  '€ 576.7 Billion',
#  '',
#  '',
#  '30',
#  'Office and computing machinery, equipment and supplies except furniture and software packages',
#  '3.1 Million',
#  '€ 102.6 Billion',
#  '',
#  '',
#  '15',
#  'Food, beverages, tobacco and related products',
#  '3.0 Million',
#  '€ 57.2 Billion',
#  '',
#  '',
#  '45',
#  'Construction work',
#  '2.6 Million',
#  '€ 1.8 Trillion',
#  '',
#  '',
#  '39',
#  'Furniture (incl. office furniture), furnishings, domestic appliances (excl. lighting) and cleaning products',
#  '2.1 Million',
#  '€ 60.6 Billion',
#  '',
#  '',
#  '44',
#  'Construction structures and materials; auxiliary products to construction (except electric apparatus)',
#  '1.8 Million',
#  '€ 80.8 Billion',
#  '',
#  '',
#  '71',
# ...

# %%
del z[0:6]

# %%
while("" in z):
    z.remove("")
z
# Out:
# ['33',
#  'Medical equipments, pharmaceuticals and personal care products',
#  '4.6 Million',
#  '€ 576.7 Billion',
#  '30',
#  'Office and computing machinery, equipment and supplies except furniture and software packages',
#  '3.1 Million',
#  '€ 102.6 Billion',
#  '15',
#  'Food, beverages, tobacco and related products',
#  '3.0 Million',
#  '€ 57.2 Billion',
#  '45',
#  'Construction work',
#  '2.6 Million',
#  '€ 1.8 Trillion',
#  '39',
#  'Furniture (incl. office furniture), furnishings, domestic appliances (excl. lighting) and cleaning products',
#  '2.1 Million',
#  '€ 60.6 Billion',
#  '44',
#  'Construction structures and materials; auxiliary products to construction (except electric apparatus)',
#  '1.8 Million',
#  '€ 80.8 Billion',
#  '71',
#  'Architectural, construction, engineering and inspection services',
#  '969,369',
#  '€ 255.1 Billion',
#  '03',
#  'Agricultural, farming, fishing, forestry and related products',
#  '943,669',
#  '€ 6.9 Billion',
#  '34',
# ...

# %%
def split(list_a, chunk_size):
    for i in range(0, len(list_a), chunk_size):
        yield list_a[i:i + chunk_size]

chunk_size = 4
x=list(split(z, chunk_size))
print(x)
# Out:
# [['33', 'Medical equipments, pharmaceuticals and personal care products', '4.6 Million', '€ 576.7 Billion'], ['30', 'Office and computing machinery, equipment and supplies except furniture and software packages', '3.1 Million', '€ 102.6 Billion'], ['15', 'Food, beverages, tobacco and related products', '3.0 Million', '€ 57.2 Billion'], ['45', 'Construction work', '2.6 Million', '€ 1.8 Trillion'], ['39', 'Furniture (incl. office furniture), furnishings, domestic appliances (excl. lighting) and cleaning products', '2.1 Million', '€ 60.6 Billion'], ['44', 'Construction structures and materials; auxiliary products to construction (except electric apparatus)', '1.8 Million', '€ 80.8 Billion'], ['71', 'Architectural, construction, engineering and inspection services', '969,369', '€ 255.1 Billion'], ['03', 'Agricultural, farming, fishing, forestry and related products', '943,669', '€ 6.9 Billion'], ['34', 'Transport equipment and auxiliary products to transportation', '929,373', '€ 273.0 Bi
# ...

# %%
import urllib
import re
link=[]
for i in soup.findAll('a'):
    link.append(i.get('href'))
link
# Out:
# ['/all/start',
#  None,
#  '/all/start',
#  '/all/',
#  '/all/dashboards/market-analysis',
#  '/all/search/tender',
#  '/all/download',
#  '/all/about/about-opentender',
#  '/all/donate',
#  '/all/dashboards/market-analysis',
#  '/all/dashboards/administrative-capacity',
#  '/all/dashboards/transparency',
#  '/all/dashboards/integrity',
#  '/all/',
#  None,
#  None,
#  '/all/sector/33',
#  '/all/sector/30',
#  '/all/sector/15',
#  '/all/sector/45',
#  '/all/sector/39',
#  '/all/sector/44',
#  '/all/sector/71',
#  '/all/sector/03',
#  '/all/sector/34',
#  '/all/sector/79',
#  '/all/sector/50',
#  '/all/sector/22',
#  '/all/sector/31',
#  '/all/sector/24',
#  '/all/sector/90',
#  '/all/sector/42',
#  '/all/sector/09',
#  '/all/sector/18',
#  '/all/sector/72',
#  '/all/sector/32',
#  '/all/sector/38',
#  '/all/sector/66',
#  '/all/sector/85',
#  '/all/sector/60',
#  '/all/sector/80',
#  '/all/sector/19',
#  '/all/sector/48',
#  '/all/sector/55',
#  '/all/sector/77',
# ...

# %%
del link[0:16]
link
# Out:
# ['/all/sector/33',
#  '/all/sector/30',
#  '/all/sector/15',
#  '/all/sector/45',
#  '/all/sector/39',
#  '/all/sector/44',
#  '/all/sector/71',
#  '/all/sector/03',
#  '/all/sector/34',
#  '/all/sector/79',
#  '/all/sector/50',
#  '/all/sector/22',
#  '/all/sector/31',
#  '/all/sector/24',
#  '/all/sector/90',
#  '/all/sector/42',
#  '/all/sector/09',
#  '/all/sector/18',
#  '/all/sector/72',
#  '/all/sector/32',
#  '/all/sector/38',
#  '/all/sector/66',
#  '/all/sector/85',
#  '/all/sector/60',
#  '/all/sector/80',
#  '/all/sector/19',
#  '/all/sector/48',
#  '/all/sector/55',
#  '/all/sector/77',
#  '/all/sector/35',
#  '/all/sector/37',
#  '/all/sector/92',
#  '/all/sector/14',
#  '/all/sector/64',
#  '/all/sector/98',
#  '/all/sector/16',
#  '/all/sector/43',
#  '/all/sector/73',
#  '/all/sector/63',
#  '/all/sector/75',
#  '/all/sector/70',
#  '/all/sector/65',
#  '/all/sector/51',
#  '/all/sector/41',
#  '/all/sector/76',
#  '/all/sector/7',
#  '/all/sector/2',
# ...

# %%
del link[58:]
link
# Out:
# ['/all/sector/33',
#  '/all/sector/30',
#  '/all/sector/15',
#  '/all/sector/45',
#  '/all/sector/39',
#  '/all/sector/44',
#  '/all/sector/71',
#  '/all/sector/03',
#  '/all/sector/34',
#  '/all/sector/79',
#  '/all/sector/50',
#  '/all/sector/22',
#  '/all/sector/31',
#  '/all/sector/24',
#  '/all/sector/90',
#  '/all/sector/42',
#  '/all/sector/09',
#  '/all/sector/18',
#  '/all/sector/72',
#  '/all/sector/32',
#  '/all/sector/38',
#  '/all/sector/66',
#  '/all/sector/85',
#  '/all/sector/60',
#  '/all/sector/80',
#  '/all/sector/19',
#  '/all/sector/48',
#  '/all/sector/55',
#  '/all/sector/77',
#  '/all/sector/35',
#  '/all/sector/37',
#  '/all/sector/92',
#  '/all/sector/14',
#  '/all/sector/64',
#  '/all/sector/98',
#  '/all/sector/16',
#  '/all/sector/43',
#  '/all/sector/73',
#  '/all/sector/63',
#  '/all/sector/75',
#  '/all/sector/70',
#  '/all/sector/65',
#  '/all/sector/51',
#  '/all/sector/41',
#  '/all/sector/76',
#  '/all/sector/7',
#  '/all/sector/2',
# ...

# %%
len(link)
# Out:
# 58

# %%
base_path='https://opentender.eu'
full_length=[]
for i in range(0,58):
    full_length.append(base_path+link[i])

# %%
full_length
# Out:
# ['https://opentender.eu/all/sector/33',
#  'https://opentender.eu/all/sector/30',
#  'https://opentender.eu/all/sector/15',
#  'https://opentender.eu/all/sector/45',
#  'https://opentender.eu/all/sector/39',
#  'https://opentender.eu/all/sector/44',
#  'https://opentender.eu/all/sector/71',
#  'https://opentender.eu/all/sector/03',
#  'https://opentender.eu/all/sector/34',
#  'https://opentender.eu/all/sector/79',
#  'https://opentender.eu/all/sector/50',
#  'https://opentender.eu/all/sector/22',
#  'https://opentender.eu/all/sector/31',
#  'https://opentender.eu/all/sector/24',
#  'https://opentender.eu/all/sector/90',
#  'https://opentender.eu/all/sector/42',
#  'https://opentender.eu/all/sector/09',
#  'https://opentender.eu/all/sector/18',
#  'https://opentender.eu/all/sector/72',
#  'https://opentender.eu/all/sector/32',
#  'https://opentender.eu/all/sector/38',
#  'https://opentender.eu/all/sector/66',
#  'https://opentender.eu/all/sector/85',
# ...

# %%
j=requests.get(full_length[0])

# %%
full_length[0]
# Out:
# 'https://opentender.eu/all/sector/33'

# %%
x[0:3]
# Out:
# [['33',
#   'Medical equipments, pharmaceuticals and personal care products',
#   '4.6 Million',
#   '€ 576.7 Billion'],
#  ['30',
#   'Office and computing machinery, equipment and supplies except furniture and software packages',
#   '3.1 Million',
#   '€ 102.6 Billion'],
#  ['15',
#   'Food, beverages, tobacco and related products',
#   '3.0 Million',
#   '€ 57.2 Billion']]

# %%
import json

with open("Tender_Data", "w") as fp:
    json.dump(x,fp)
